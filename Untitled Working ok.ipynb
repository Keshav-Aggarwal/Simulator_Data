# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from skimage.feature import hog
import glob
import os
import sklearn
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
import itertools
from sklearn import grid_search
from sklearn.preprocessing import StandardScaler
from scipy.ndimage.measurements import label

# %%
vehiclesDir = os.listdir('vehicles')
imagesVehiclePath = []
for folder in vehiclesDir:
    path = os.path.join(os.path.join('vehicles',folder), '*.png')
    imagesVehiclePath.append(glob.glob(path))
    
nonVehiclesDir = os.listdir('non-vehicles')
nonImagesVehiclePath = []
for folder in nonVehiclesDir:
    path = os.path.join(os.path.join('non-vehicles',folder), '*.png')
    nonImagesVehiclePath.append(glob.glob(path))

# %%
vehicle = []
nonVehicle = []
for imgDirPath in imagesVehiclePath:
    for imgPath in imgDirPath:
        vehicle.append(cv2.cvtColor(cv2.imread(imgPath), cv2.COLOR_BGR2RGB))

for imgDirPath in nonImagesVehiclePath:
    for imgPath in imgDirPath:
        nonVehicle.append(cv2.cvtColor(cv2.imread(imgPath), cv2.COLOR_BGR2RGB))

# %%
print("Number of Vehicle Data samples ", len(vehicle))
print("Number of Non-Vehicle Data samples ", len(nonVehicle))
# Out:
# Number of Vehicle Data samples  8792
# Number of Non-Vehicle Data samples  8968

# %%
y_label_class = [1,0]
y_label_vehicle = [y_label_class[0]]*len(vehicle)
y_label_nonVehicle = [y_label_class[1]]*len(nonVehicle)

data = np.vstack([vehicle, nonVehicle])
label = np.hstack([y_label_vehicle, y_label_nonVehicle])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.1, shuffle = True, random_state=43)

# %% [markdown]
# #### Generate Features

# %%
#UTILITY FUNCTIONS
def hogR(img,pix_per_cell = 16, cell_per_block = 2, orient = 11):
    hg = hog(img, orientations=orient, pixels_per_cell=(pix_per_cell, pix_per_cell), cells_per_block=(cell_per_block, cell_per_block), visualise=False, feature_vector=True)
    return hg

def hogFeatures(data):
    hogFeaturesFirst = hogR(data[:,:,0])
    hogFeaturesSecond = hogR(data[:,:,1])
    hogFeaturesThird = hogR(data[:,:,2])
    
    return np.concatenate((hogFeaturesFirst, hogFeaturesSecond, hogFeaturesThird))

def histogram(data):
    
    histFirst = np.histogram(data[:, :, 0], bins=32, range=(0,255))
    histSecond = np.histogram(data[:, :, 1], bins=32, range=(0,255))
    histThird = np.histogram(data[:, :, 2], bins=32, range=(0,255))
    
    return np.concatenate((histFirst[0], histSecond[0], histThird[0]))

def bin_spatial(data):
    return (cv2.resize(data, (32, 32)).ravel())
    
def scaling(data, stdscl, fit = False):
    if(fit == True):
        stdscl.fit(data)
    return stdscl.transform(data), stdscl
    
    
def decomposition(data, pc, fit = False):
    if(fit == True):
        pc = pc.fit(data)
    return pc.transform(data), pc
    
def transform(imgs, pc, pcfit, std, stdfit):
    features = []
    for img in imgs:
        img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
        feature = []
        feature.append(histogram(img))
#         feature.append(bin_spatial(img))
        feature.append(hogFeatures(img))
    
        features.append(np.concatenate(np.array(feature)))
    stdFeatures, std = scaling(features, std, stdfit)
    pcFeatures = stdFeatures
#     pcFeatures, pc = decomposition(stdFeatures, pc, pcfit)
    return pcFeatures, pc, std

# %%
# %%time
pc = PCA(10)
std = StandardScaler()
features_extracted, pc, std = transform(X_train, pc, True, std, True)
test_features, pcT, stdT = transform(X_test, pc, False, std, False)
# Out:
# Wall time: 4min 16s

# %% [markdown]
# As it can be seen from the below Data that we have 7056 features. We will use PCA for reducing the dimensions.

# %%
print("Dimension of the extracted featrues is ", np.array(features_extracted).shape)
# Out:
# Dimension of the extracted featrues is  (15984, 1284)

# %% [markdown]
# ### Train Classifier

# %%
# %time
from sklearn.ensemble import ExtraTreesClassifier
treeClf = ExtraTreesClassifier(n_estimators=500)
treeClf.fit(features_extracted, y_train)
# Out:
# Wall time: 0 ns
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
# %%time
from sklearn.svm import LinearSVC
classifier = LinearSVC()
parameters = {'C':[1]}
clf = grid_search.GridSearchCV(classifier, parameters, cv=5, verbose=5) 
clf.fit(features_extracted, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] C=1 .............................................................
# [CV] .................................... C=1, score=0.988427 -   3.7s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.8s remaining:    0.0s
# [CV] C=1 .............................................................
# [CV] .................................... C=1, score=0.987175 -   3.9s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    7.8s remaining:    0.0s
# [CV] C=1 .............................................................
# [CV] .................................... C=1, score=0.986550 -   3.5s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   11.4s remaining:    0.0s
# [CV] C=1 .............................................................
# [CV] .................................... C=1, score=0.987801 -   3.3s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   14.8s remaining:    0.0s
# ...

# %%
print(clf.score(test_features, y_test))
# Out:
# 0.990427927928

# %%
def plot_confusion_matrix(cm, classes,title='Confusion matrix',cmap=plt.cm.Blues):
    print('Confusion matrix')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
y_pred = clf.predict(test_features)
cm = confusion_matrix(y_test, y_pred)

plot_confusion_matrix(cm, y_label_class)
# Out:
# Confusion matrix

# %% [markdown]
# ### Checking the car in an image

# %%
from random import randint
def getCroppedScene(img, window):
    p1 = window[0]
    p2 = window[1]
    return img[p1[0]:p2[0], p1[1]:p2[1]]

def slide_window(img, x_start_stop=[None, None], y_start_stop=[None, None], xy_window=(64, 64), xy_overlap=(0.5, 0.5)):
    # If x and/or y start/stop positions not defined, set to image size
    if x_start_stop[0] == None:
        x_start_stop[0] = 0
    if x_start_stop[1] == None:
        x_start_stop[1] = img.shape[1]
    if y_start_stop[0] == None:
        y_start_stop[0] = 0
    if y_start_stop[1] == None:
        y_start_stop[1] = img.shape[0]
        
    # Compute the span of the region to be searched    
    xspan = x_start_stop[1] - x_start_stop[0]
    yspan = y_start_stop[1] - y_start_stop[0]
    # Compute the number of pixels per step in x/y
    nx_pix_per_step = np.int(xy_window[0]*(1 - xy_overlap[0]))
    ny_pix_per_step = np.int(xy_window[1]*(1 - xy_overlap[1]))
    # Compute the number of windows in x/y
    nx_buffer = np.int(xy_window[0]*(xy_overlap[0]))
    ny_buffer = np.int(xy_window[1]*(xy_overlap[1]))
    nx_windows = np.int((xspan-nx_buffer)/nx_pix_per_step) 
    ny_windows = np.int((yspan-ny_buffer)/ny_pix_per_step) 
    # Initialize a list to append window positions to
    window_list = []
    for ys in range(ny_windows):
        for xs in range(nx_windows):
            # Calculate window position
            startx = xs*nx_pix_per_step + x_start_stop[0]
            endx = startx + xy_window[0]
            starty = ys*ny_pix_per_step + y_start_stop[0]
            endy = starty + xy_window[1]
            # Append window position to list
            window_list.append(((startx, starty), (endx, endy)))
    # Return the list of windows
    return window_list

def draw_boxes(img, bboxes, color=(0, 0, 255), thick=3):
    # Make a copy of the image
 
    
    imcopy = np.copy(img)
    # Iterate through the bounding boxes
    for bbox in bboxes:
        r = ((randint(0,255)))
        g = (randint(0,255))
        b = (randint(0,255))
        # Draw a rectangle given bbox coordinates
        cv2.rectangle(imcopy, bbox[0], bbox[1], (r,g,b), thick)
    # Return the image copy with boxes drawn
    return imcopy

# %%
def search_windows(img, windows, clf):

    #1) Create an empty list to receive positive detection windows
    on_windows = []
    #2) Iterate over all windows in the list
    for window in windows:
        #3) Extract the test window from original image
        test_img = cv2.resize(img[window[0][1]:window[1][1], window[0][0]:window[1][0]], (64, 64))      
        test_features, pc1, std1 = transform([test_img], pc, False, std, False)
        
        prediction = clf.predict(test_features)
        
        if prediction == 1:
            score = clf.decision_function(test_features)
            if(score >= 1.0):
#                 print("Score is ", score)
            
                on_windows.append(window)
    #8) Return windows for positive detections
    return on_windows

# %%
# imgTest = plt.imread('test6.jpg')
# imgTest1 = plt.imread('test6.jpg')
# windows = []
# # windows += slide_window(imgTest, x_start_stop=[None, None], y_start_stop=[400,600], xy_window=(192, 128), xy_overlap=(0.75, 0.75))
# windows += slide_window(imgTest, x_start_stop=[None, None], y_start_stop=[350,600], xy_window=(64, 64), xy_overlap=(0.1, 0.1))
# windows += slide_window(imgTest, x_start_stop=[None, None], y_start_stop=[400,None], xy_window=(96, 96), xy_overlap=(0.5, 0.2))
# windows += slide_window(imgTest, x_start_stop=[None, None], y_start_stop=[400,700], xy_window=(128, 128), xy_overlap=(0.75, 0.75))
# fig = plt.figure(figsize=(16,8))
# plt.subplot(121)
# plt.imshow(draw_boxes(imgTest, windows))
# Test = search_windows(imgTest1, windows, clf)
# plt.subplot(122)
# img1 = (draw_boxes(imgTest1, Test))
# plt.imshow(img1)

# %%
imgTest = plt.imread('test5.jpg')
imgTest1 = plt.imread('test5.jpg')
windows = []
windows += slide_window(imgTest, x_start_stop=[None, None], y_start_stop=[400,600], xy_window=(160, 128), xy_overlap=(0.75, 0.8))
windows += slide_window(imgTest, x_start_stop=[None, None], y_start_stop=[350,500], xy_window=(64, 64), xy_overlap=(0.75, 0.25))
windows += slide_window(imgTest, x_start_stop=[None, None], y_start_stop=[400,650], xy_window=(96, 96), xy_overlap=(0.65, 0.65))
windows += slide_window(imgTest, x_start_stop=[None, None], y_start_stop=[400,650], xy_window=(128, 128), xy_overlap=(0.75, 0.75))
print("Number of widnows are ", len(windows))
fig = plt.figure(figsize=(16,8))
plt.subplot(121)
plt.imshow(draw_boxes(imgTest, windows))

Test = search_windows(imgTest1, windows, clf)

plt.subplot(122)
img1 = (draw_boxes(imgTest1, Test))
plt.imshow(img1)
# Out:
# Number of widnows are  569

# %%
heatMapCheck = plt.imread('test5.jpg')
heat = np.zeros_like(heatMapCheck[:,:,0]).astype(np.float)

def add_heat(heatmap, bbox_list):
    # Iterate through list of bboxes
    for box in bbox_list:
        # Add += 1 for all pixels inside each bbox
        # Assuming each "box" takes the form ((x1, y1), (x2, y2))
        heatmap[box[0][1]:box[1][1], box[0][0]:box[1][0]] += 1

    # Return updated heatmap
    return heatmap# Iterate through list of bboxes
    
def apply_threshold(heatmap, threshold):
    # Zero out pixels below the threshold
    heatmap[heatmap <= threshold] = 0
    # Return thresholded map
    return heatmap

def draw_labeled_bboxes(img, labels):
    # Iterate through all detected cars
    for car_number in range(1, labels[1]+1):
        # Find pixels with each car_number label value
        nonzero = (labels[0] == car_number).nonzero()
        # Identify x and y values of those pixels
        nonzeroy = np.array(nonzero[0])
        nonzerox = np.array(nonzero[1])
        # Define a bounding box based on min/max x and y
        bbox = ((np.min(nonzerox), np.min(nonzeroy)), (np.max(nonzerox), np.max(nonzeroy)))
        # Draw the box on the image
        cv2.rectangle(img, bbox[0], bbox[1], (0,0,255), 2)
    # Return the image
    return img

# Add heat to each box in box list
heat = add_heat(heat,Test)
    
# Apply threshold to help remove false positives
heat = apply_threshold(heat,0)
# Visualize the heatmap when displaying    
heatmap = np.clip(heat, 0, 255)

# Find final boxes from heatmap using label function
labels = label(heatmap)
draw_img = draw_labeled_bboxes(np.copy(heatMapCheck), labels)
plt.figure(figsize=(16 ,16))
plt.imshow(draw_img)

# %%
# %%time
print(len(windows))

def pipeline(img):
    global i
    plt.imsave("opImg/Input"+str(i)+".jpg", img)
    heat = np.zeros_like(img[:,:,0]).astype(np.float)
    
    Test = search_windows(img, windows, clf)
    heat = add_heat(heat,Test)

    heatm = apply_threshold(heat,0)
    heatmap = np.clip(heatm, 0, 255)
    
    labels = label(heatmap)
    output =  draw_labeled_bboxes(np.copy(img), labels)
#     plt.imsave(output,("opImg/Input"+str(i)+".jpg"))
    plt.imsave("opImg/Input"+str(i)+"_1.jpg", output)
    i = i+1
    return output

heatMapCheck = plt.imread('Input345.jpg')
plt.figure(figsize=(16, 16))
plt.imshow(pipeline(heatMapCheck))
# Out:
# 569
# Wall time: 6.92 s

# %%
i = 0
import moviepy
from moviepy.editor import VideoFileClip
video_output1 = 'output.mp4'
video_input1 = VideoFileClip('project_video.mp4').subclip(30, 34)
processed_video = video_input1.fl_image(pipeline)
# %time processed_video.write_videofile(video_output1, audio=False)
video_input1.reader.close()
video_input1.audio.reader.close_proc()
# Out:
# [MoviePy] >>>> Building video output.mp4
# [MoviePy] Writing video output.mp4
#  99%|███████████████████████████████████████████████████████████████████████████████▏| 100/101 [11:07<00:06,  6.52s/it]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: output.mp4
#
# Wall time: 11min 9s

# %%
from sklearn.base import BaseEstimator, TransformerMixin
class PipelineComplete(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def preProcessData(self, data):
        hogFeaturesR = []
        for img in data:
            tempData = []
            for i in range(3):
                tempData.append(hogR(img[:,:,i]))

            hogFeaturesR.append(np.vstack(tempData))
        sampleHog = np.array(hogFeaturesR)
        sampleHog = (sampleHog.reshape((len(sampleHog),-1)))
        return sampleHog
    
    def histogram(self, data):
        hist = []
        for img in data:
            tempData = []
            for i in range(3):
                tempData.append(np.histogram(img[:, :, i], bins=32, range=(0,255)))
            hist.append(np.vstack(tempData))
        histData = np.array(hist)
        return histData.reshape(len(histData), -1)
    
    def bin_spatial(self, data):
        imgs = []
        for img in data:
            imgs.append(cv2.resize(img, (32, 32)))
        return imgs
    
    def transform(self, x, y= None):
        hogFeatures = preProcessData(x)
        histFeatures = histogram(x)
        binFeatures = bin_spatial(x)
        features = [hogFeatures, histFeatures, binFeatures]
        return np.hstack(features)
